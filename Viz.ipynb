# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
gens = np.load("generations.numpy.npy")
data = pd.DataFrame({
    "S1": gens[:, 0],
    "S2": gens[:, 1],
    "I": gens[:, 2],
    "R": gens[:, 3],
})

# %%
data.plot()
